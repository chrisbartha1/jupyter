# %% [markdown]
# # Python Data Science Notes
#
# First using NumPy module

# %%
import numpy as np
from matplotlib import pyplot as plt

test = np.array([[1, 2, 3, 9, 10, 11, 99],
                 [5, 7, 1, 2,  3,  0, 10],
                 [9, 9, 9, 9,  9,  9, 99]])

# %% [markdown]
# ### First are all of the basic **`NumPy`** functions:

# %% [raw]
#    Mean:      np.mean(test)
#    Median:    np.median(test)
#    First Q:   np.percentile(test, 25)
#    Third Q:   np.percentile(test, 75)
#    Std. Dev.: np.std(test)
#    Sorted:    np.sort(test)

# %% [markdown]
# #### Some things you may do with those functions are limitless:

# %%
np.mean(test > 10) * 100
# Out:
# 14.285714285714285

# %% [markdown]
# #### `axis=1` is *row*; `axis=0` is *column*

# %%
np.mean(test, axis=0)
# Out:
# array([ 5.        ,  6.        ,  4.33333333,  6.66666667,  7.33333333,
#         6.66666667, 69.33333333])

# %% [raw]
# Plotting a histogram with a randomly generated binomial dataset:
#    N   : The number of samples or trials
#    P   : The probability of success
#    size: The number of experiments

# %%
you = np.random.binomial(10.0, 0.30, size=10000)
friend = np.random.binomial(10.0, 0.4, size=10000)
plt.hist(plt_test, range=(0, 10), bins=10, density=True, label='You', histtype='step')
plt.hist(friend, range=(0, 10), bins=10, density=True, label='Friend', histtype='step')
plt.title('Free-Throw Experiment')
plt.xlabel('Number of Free-Throws')
plt.ylabel('Frequency')
plt.legend(loc=2)
plt.show()
